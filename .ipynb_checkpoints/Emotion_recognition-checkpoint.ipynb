# %%
import requests
import json

# %%
text=['Oh man oh man','where is this world going','Ia m soo hungry','I dont like you Cira', 'Junction food sucks','I dont know what I wanna do','How are you','What shall I do today']

# %%
import indicoio

# %%
indicoio.config.api_key = 'ca9799d5cdd695159b4e0ea7d6630072'

# %%
response=requests.get('https://api.vk.com/method/groups.getLongPollServer?group_id=174367830&access_token=fbdc5bd3cff381a236f0f30a1b58982ca4ddf1508e03a6513af837d67184c6ffa064d2a6737a897bc012e&v=5.92')

# %%
community_resp=response.json()
print(community_resp)
print(community_resp['response']['key'])
# Out:
# {'response': {'key': '7ddb0453a5fb071c2dab9548a39e457c95443832', 'server': 'https://lp.vk.com/wh174367830', 'ts': '30'}}
# 7ddb0453a5fb071c2dab9548a39e457c95443832

# %%
https://vk.com/dev/wall.get?params[owner_id]=518274537&params[count]=1&params[filter]=owner&params[extended]=1&params[v]=5.92

# %%
messages=requests.get('https://lp.vk.com/wh174367830?act=a_check&key=%s&ts=1&wait=%s'%(community_resp['response']['key'],community_resp['response']['ts']))

# %%
messages_json=messages.json()

# %%
messages_json
# Out:
# {'ts': '32',
#  'updates': [{'group_id': 174367830,
#    'object': {'attachments': [],
#     'conversation_message_id': 3,
#     'date': 1543049177,
#     'from_id': 762177,
#     'fwd_messages': [],
#     'id': 3,
#     'important': False,
#     'is_hidden': False,
#     'out': 0,
#     'peer_id': 762177,
#     'random_id': 0,
#     'text': 'hello'},
#    'type': 'message_new'},
#   {'group_id': 174367830,
#    'object': {'attachments': [],
#     'conversation_message_id': 4,
#     'date': 1543049611,
#     'from_id': -174367830,
#     'fwd_messages': [],
#     'id': 4,
#     'important': False,
#     'is_hidden': False,
#     'out': 1,
#     'peer_id': 762177,
#     'random_id': 1,
#     'text': 'hello'},
#    'type': 'message_reply'},
#   {'group_id': 174367830,
#    'object': {'from_id': 762177, 'state': 'typing', 'to_id': -174367830},
#    'type': 'message_typing_state'},
#   {'group_id': 174367830,
#    'object': {'attachments': [],
#     'conversation_message_id': 5,
#     'date': 1543053896,
#     'from_id': 762177,
#     'fwd_messages': [],
#     'id': 5,
#     'important': False,
#     'is_hidden': False,
#     'out': 0,
#     'peer_id': 762177,
#     'random_id': 0,
#     'text': 'test'},
#    'type': 'message_new'},
#   {'group_id': 174367830,
#    'object': {'attachments': [],
#     'conversation_message_id': 6,
#     'date': 1543054234,
#     'from_id': -174367830,
#     'fwd_messages': [],
#     'id': 6,
#     'important': False,
#     'is_hidden': False,
#     'out': 1,
#     'peer_id': 762177,
#     'random_id': 1,
#     'text': 'hello'},
#    'type': 'message_reply'},
#   {'group_id': 174367830,
#    'object': {'from_id': 762177, 'state': 'typing', 'to_id': -174367830},
#    'type': 'message_typing_state'},
#   {'group_id': 174367830,
#    'object': {'attachments': [],
#     'conversation_message_id': 7,
#     'date': 1543054489,
#     'from_id': 762177,
#     'fwd_messages': [],
#     'id': 7,
#     'important': False,
#     'is_hidden': False,
#     'out': 0,
#     'peer_id': 762177,
#     'random_id': 0,
#     'text': 'test'},
#    'type': 'message_new'},
#   {'group_id': 174367830,
#    'object': {'attachments': [],
#     'conversation_message_id': 1,
#     'date': 1543060229,
#     'from_id': 518240818,
#     'fwd_messages': [],
#     'id': 8,
#     'important': False,
#     'is_hidden': False,
#     'out': 0,
#     'peer_id': 518240818,
#     'random_id': 0,
#     'text': 'Hihi'},
#    'type': 'message_new'},
#   {'group_id': 174367830,
#    'object': {'key': '', 'user_id': 518240818},
#    'type': 'message_allow'},
#   {'group_id': 174367830,
#    'object': {'from_id': 518240818, 'state': 'typing', 'to_id': -174367830},
#    'type': 'message_typing_state'},
#   {'group_id': 174367830,
#    'object': {'attachments': [],
#     'conversation_message_id': 2,
#     'date': 1543060647,
#     'from_id': 518240818,
#     'fwd_messages': [],
#     'id': 9,
#     'important': False,
#     'is_hidden': False,
#     'out': 0,
#     'peer_id': 518240818,
#     'random_id': 0,
#     'text': "Cira, I don't know what to do"},
#    'type': 'message_new'},
#   {'group_id': 174367830,
#    'object': {'from_id': 518240818, 'state': 'typing', 'to_id': -174367830},
#    'type': 'message_typing_state'},
#   {'group_id': 174367830,
#    'object': {'attachments': [],
#     'conversation_message_id': 3,
#     'date': 1543060862,
#     'from_id': 518240818,
#     'fwd_messages': [],
#     'id': 10,
#     'important': False,
#     'is_hidden': False,
#     'out': 0,
#     'peer_id': 518240818,
#     'random_id': 0,
#     'text': 'Hi, how are you doing?'},
#    'type': 'message_new'},
#   {'group_id': 174367830,
#    'object': {'attachments': [],
#     'conversation_message_id': 8,
#     'date': 1543061054,
#     'from_id': -174367830,
#     'fwd_messages': [],
#     'id': 11,
#     'important': False,
#     'is_hidden': False,
#     'out': 1,
#     'peer_id': 762177,
#     'random_id': 1,
#     'text': 'hello'},
#    'type': 'message_reply'},
#   {'group_id': 174367830,
#    'object': {'from_id': 518240818, 'state': 'typing', 'to_id': -174367830},
#    'type': 'message_typing_state'},
#   {'group_id': 174367830,
#    'object': {'attachments': [],
#     'conversation_message_id': 4,
#     'date': 1543061686,
#     'from_id': 518240818,
#     'fwd_messages': [],
#     'id': 12,
#     'important': False,
#     'is_hidden': False,
#     'out': 0,
#     'peer_id': 518240818,
#     'random_id': 0,
#     'text': 'I hate you'},
#    'type': 'message_new'},
#   {'group_id': 174367830,
#    'object': {'attachments': [],
#     'conversation_message_id': 5,
#     'date': 1543061783,
#     'from_id': -174367830,
#     'fwd_messages': [],
#     'id': 13,
#     'important': False,
#     'is_hidden': False,
#     'out': 1,
#     'peer_id': 518240818,
#     'random_id': 1,
#     'text': "['calm down']"},
#    'type': 'message_reply'},
#   {'group_id': 174367830,
#    'object': {'from_id': 518240818, 'state': 'typing', 'to_id': -174367830},
#    'type': 'message_typing_state'},
#   {'group_id': 174367830,
#    'object': {'attachments': [],
#     'conversation_message_id': 6,
#     'date': 1543061823,
#     'from_id': 518240818,
#     'fwd_messages': [],
#     'id': 14,
#     'important': False,
#     'is_hidden': False,
#     'out': 0,
#     'peer_id': 518240818,
#     'random_id': 0,
#     'text': 'I hate you'},
#    'type': 'message_new'},
#   {'group_id': 174367830,
#    'object': {'from_id': 762177, 'state': 'typing', 'to_id': -174367830},
#    'type': 'message_typing_state'},
#   {'group_id': 174367830,
#    'object': {'from_id': 762177, 'state': 'typing', 'to_id': -174367830},
#    'type': 'message_typing_state'},
#   {'group_id': 174367830,
#    'object': {'attachments': [],
#     'conversation_message_id': 9,
#     'date': 1543061931,
#     'from_id': 762177,
#     'fwd_messages': [],
#     'id': 15,
#     'important': False,
#     'is_hidden': False,
#     'out': 0,
#     'peer_id': 762177,
#     'random_id': 0,
#     'text': 'test'},
#    'type': 'message_new'},
#   {'group_id': 174367830,
#    'object': {'attachments': [],
#     'conversation_message_id': 10,
#     'date': 1543062594,
#     'from_id': -174367830,
#     'fwd_messages': [],
#     'id': 16,
#     'important': False,
#     'is_hidden': False,
#     'out': 1,
#     'peer_id': 762177,
#     'random_id': 4,
#     'text': 'hahaha'},
#    'type': 'message_reply'},
#   {'group_id': 174367830,
#    'object': {'from_id': 762177, 'state': 'typing', 'to_id': -174367830},
#    'type': 'message_typing_state'},
#   {'group_id': 174367830,
#    'object': {'attachments': [],
#     'conversation_message_id': 11,
#     'date': 1543065109,
#     'from_id': 762177,
#     'fwd_messages': [],
#     'id': 17,
#     'important': False,
#     'is_hidden': False,
#     'out': 0,
#     'peer_id': 762177,
#     'random_id': 0,
#     'text': 'hi cira'},
#    'type': 'message_new'},
#   {'group_id': 174367830,
#    'object': {'from_id': 762177, 'state': 'typing', 'to_id': -174367830},
#    'type': 'message_typing_state'},
#   {'group_id': 174367830,
#    'object': {'attachments': [],
#     'conversation_message_id': 12,
#     'date': 1543066962,
#     'from_id': 762177,
#     'fwd_messages': [],
#     'id': 18,
#     'important': False,
#     'is_hidden': False,
#     'out': 0,
#     'peer_id': 762177,
#     'random_id': 0,
#     'text': 'cira?'},
#    'type': 'message_new'},
#   {'group_id': 174367830,
#    'object': {'attachments': [],
#     'conversation_message_id': 1,
#     'date': 1543067086,
#     'from_id': 518274537,
#     'fwd_messages': [],
#     'id': 19,
#     'important': False,
#     'is_hidden': False,
#     'out': 0,
#     'peer_id': 518274537,
#     'random_id': 0,
#     'text': 'Hi cira!'},
#    'type': 'message_new'},
#   {'group_id': 174367830,
#    'object': {'key': '', 'user_id': 518274537},
#    'type': 'message_allow'},
#   {'group_id': 174367830,
#    'object': {'from_id': 762177, 'state': 'typing', 'to_id': -174367830},
#    'type': 'message_typing_state'},
#   {'group_id': 174367830,
#    'object': {'attachments': [],
#     'conversation_message_id': 13,
#     'date': 1543067210,
#     'from_id': 762177,
#     'fwd_messages': [],
#     'id': 20,
#     'important': False,
#     'is_hidden': False,
#     'out': 0,
#     'peer_id': 762177,
#     'random_id': 0,
#     'text': 'tyu'},
#    'type': 'message_new'}]}

# %%
updates_json=messages_json['updates']
new_messages=[updates_json[i] for i in range(len(updates_json)) if updates_json[i]['type']=='message_new']

# %%
new_messages
# Out:
# [{'group_id': 174367830,
#   'object': {'attachments': [],
#    'conversation_message_id': 3,
#    'date': 1543049177,
#    'from_id': 762177,
#    'fwd_messages': [],
#    'id': 3,
#    'important': False,
#    'is_hidden': False,
#    'out': 0,
#    'peer_id': 762177,
#    'random_id': 0,
#    'text': 'hello'},
#   'type': 'message_new'},
#  {'group_id': 174367830,
#   'object': {'attachments': [],
#    'conversation_message_id': 5,
#    'date': 1543053896,
#    'from_id': 762177,
#    'fwd_messages': [],
#    'id': 5,
#    'important': False,
#    'is_hidden': False,
#    'out': 0,
#    'peer_id': 762177,
#    'random_id': 0,
#    'text': 'test'},
#   'type': 'message_new'},
#  {'group_id': 174367830,
#   'object': {'attachments': [],
#    'conversation_message_id': 7,
#    'date': 1543054489,
#    'from_id': 762177,
#    'fwd_messages': [],
#    'id': 7,
#    'important': False,
#    'is_hidden': False,
#    'out': 0,
#    'peer_id': 762177,
#    'random_id': 0,
#    'text': 'test'},
#   'type': 'message_new'},
#  {'group_id': 174367830,
#   'object': {'attachments': [],
#    'conversation_message_id': 1,
#    'date': 1543060229,
#    'from_id': 518240818,
#    'fwd_messages': [],
#    'id': 8,
#    'important': False,
#    'is_hidden': False,
#    'out': 0,
#    'peer_id': 518240818,
#    'random_id': 0,
#    'text': 'Hihi'},
#   'type': 'message_new'},
#  {'group_id': 174367830,
#   'object': {'attachments': [],
#    'conversation_message_id': 2,
#    'date': 1543060647,
#    'from_id': 518240818,
#    'fwd_messages': [],
#    'id': 9,
#    'important': False,
#    'is_hidden': False,
#    'out': 0,
#    'peer_id': 518240818,
#    'random_id': 0,
#    'text': "Cira, I don't know what to do"},
#   'type': 'message_new'},
#  {'group_id': 174367830,
#   'object': {'attachments': [],
#    'conversation_message_id': 3,
#    'date': 1543060862,
#    'from_id': 518240818,
#    'fwd_messages': [],
#    'id': 10,
#    'important': False,
#    'is_hidden': False,
#    'out': 0,
#    'peer_id': 518240818,
#    'random_id': 0,
#    'text': 'Hi, how are you doing?'},
#   'type': 'message_new'},
#  {'group_id': 174367830,
#   'object': {'attachments': [],
#    'conversation_message_id': 4,
#    'date': 1543061686,
#    'from_id': 518240818,
#    'fwd_messages': [],
#    'id': 12,
#    'important': False,
#    'is_hidden': False,
#    'out': 0,
#    'peer_id': 518240818,
#    'random_id': 0,
#    'text': 'I hate you'},
#   'type': 'message_new'},
#  {'group_id': 174367830,
#   'object': {'attachments': [],
#    'conversation_message_id': 6,
#    'date': 1543061823,
#    'from_id': 518240818,
#    'fwd_messages': [],
#    'id': 14,
#    'important': False,
#    'is_hidden': False,
#    'out': 0,
#    'peer_id': 518240818,
#    'random_id': 0,
#    'text': 'I hate you'},
#   'type': 'message_new'},
#  {'group_id': 174367830,
#   'object': {'attachments': [],
#    'conversation_message_id': 9,
#    'date': 1543061931,
#    'from_id': 762177,
#    'fwd_messages': [],
#    'id': 15,
#    'important': False,
#    'is_hidden': False,
#    'out': 0,
#    'peer_id': 762177,
#    'random_id': 0,
#    'text': 'test'},
#   'type': 'message_new'},
#  {'group_id': 174367830,
#   'object': {'attachments': [],
#    'conversation_message_id': 11,
#    'date': 1543065109,
#    'from_id': 762177,
#    'fwd_messages': [],
#    'id': 17,
#    'important': False,
#    'is_hidden': False,
#    'out': 0,
#    'peer_id': 762177,
#    'random_id': 0,
#    'text': 'hi cira'},
#   'type': 'message_new'},
#  {'group_id': 174367830,
#   'object': {'attachments': [],
#    'conversation_message_id': 12,
#    'date': 1543066962,
#    'from_id': 762177,
#    'fwd_messages': [],
#    'id': 18,
#    'important': False,
#    'is_hidden': False,
#    'out': 0,
#    'peer_id': 762177,
#    'random_id': 0,
#    'text': 'cira?'},
#   'type': 'message_new'},
#  {'group_id': 174367830,
#   'object': {'attachments': [],
#    'conversation_message_id': 1,
#    'date': 1543067086,
#    'from_id': 518274537,
#    'fwd_messages': [],
#    'id': 19,
#    'important': False,
#    'is_hidden': False,
#    'out': 0,
#    'peer_id': 518274537,
#    'random_id': 0,
#    'text': 'Hi cira!'},
#   'type': 'message_new'},
#  {'group_id': 174367830,
#   'object': {'attachments': [],
#    'conversation_message_id': 13,
#    'date': 1543067210,
#    'from_id': 762177,
#    'fwd_messages': [],
#    'id': 20,
#    'important': False,
#    'is_hidden': False,
#    'out': 0,
#    'peer_id': 762177,
#    'random_id': 0,
#    'text': 'tyu'},
#   'type': 'message_new'}]

# %%
lastmess=new_messages[-2]
text_lastmess=lastmess['object']['text']

# %%
emotion_lastmess=indicoio.emotion(text_lastmess)

# %%
emot_dic={}
emot_dic['anger']=['calm down']

# %%
emotion_lastmess
# Out:
# {'anger': 0.15297941863536835,
#  'fear': 0.20247909426689148,
#  'joy': 0.22389107942581177,
#  'sadness': 0.12785707414150238,
#  'surprise': 0.292793333530426}

# %%
if emotion_lastmess['anger']>0.3:
    resp_mes=emot_dic['anger']
print(resp_mes)

# %%
requests.post('https://api.vk.com/method/messages.send?peer_id=518240818&random_id=1&message=%s&access_token=fbdc5bd3cff381a236f0f30a1b58982ca4ddf1508e03a6513af837d67184c6ffa064d2a6737a897bc012e&v=5.92'%resp_mes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-79de48958988> in <module>()
# ----> 1 requests.post('https://api.vk.com/method/messages.send?peer_id=518274537&random_id=1&message=%s&access_token=fbdc5bd3cff381a236f0f30a1b58982ca4ddf1508e03a6513af837d67184c6ffa064d2a6737a897bc012e&v=5.92'%resp_mes)
#
# NameError: name 'resp_mes' is not defined
